# %%
#creating the personality test and answer key as a dictionary
test_q = {
    1 : {
        'restrained' : 'A',
        'forceful' : 'B',
        'careful' : 'C',
        'expressive' : 'D'
    },
    2 : {
        'pioneering' : 'A',
        'correct' : 'B',
        'exciting' : 'C',
        'satisfied' : 'D'
    },
    3 : {
        'willing' : 'C',
        'animated' : 'B',
        'bold' : 'A',
        'precise' : 'D'
    },
    4 : {
        'argumentative' : 'A',
        'doubting' : 'D',
        'indecisive' : 'C',
        'unpredictable' : 'B'
    },
    5 : {
        'respectful' : 'D',
        'out-going' : 'B',
        'patient' : 'C',
        'daring' : 'A'
    },
    6 : {
        'persuasive' : 'B',
        'self-reliant' : 'A',
        'logical' : 'D',
        'gentle' : 'C'
    },
    7 : {
        'cautious' : 'C',
        'even-tempered' : 'D',
        'decisive' : 'B',
        'life-of-the-party' : 'A'
    },
    8 : {
        'popular' : 'B',
        'assertive' : 'A',
        'perfectionist' : 'D',
        'generous' : 'C'
    },
    9 : {
        'colorful' : 'D',
        'modest' : 'A',
        'easy-going' : 'C',
        'unyielding' : 'B'
    },
    10 : {
        'systematic' : 'C',
        'optimistic' : 'B',
        'persistent' : 'D',
        'accommodating' : 'A'
    },
    11 : {
        'relentless' : 'A',
        'humble' : 'D',
        'neighborly' : 'C',
        'talkative' : 'B'
    },
    12 : {
        'friendly' : 'D',
        'observant' : 'C',
        'playful' : 'A',
        'strong-willed' : 'B'
    },
    13 : {
        'charming' : 'B',
        'adventurous' : 'A',
        'disciplined' : 'D',
        'deliberate' : 'C'
    },
    14 : {
        'restrained' : 'C',
        'steady' : 'D',
        'aggressive' : 'B',
        'attractive' : 'A'
    },
    15 : {
        'enthusiastic' : 'D',
        'analytical' : 'A',
        'sympathetic' : 'C',
        'determined' : 'B'
    },
    16 : {
        'commanding' : 'A',
        'impulsive' : 'B',
        'slow-paced' : 'C',
        'critical' : 'D'
    },
    17 : {
        'consistent' : 'B',
        'force-of-character' : 'C',
        'lively' : 'D',
        'laid-back' : 'A'
    },
    18 : {
        'influential' : 'C',
        'kind' : 'A',
        'independent' : 'B',
        'orderly' : 'D'
    },
    19 : {
        'idealistic' : 'D',
        'outgoing' : 'B',
        'pleasant' : 'C',
        'out-spoken' : 'A'
    },
    20 : {
        'impatient' : 'A',
        'serious' : 'D',
        'procrastinator' : 'C',
        'emotional' : 'B' 
    },
    21 : {
        'competitive' : 'A',
        'spontaneous' : 'B',
        'loyal' : 'C',
        'thoughtful' : 'D'
    },
    22 : {
        'self-sacrificing' : 'D',
        'considerate' : 'C',
        'convincing' : 'B',
        'courageous' : 'A'
    },
    23 : {
        'dependent' : 'D',
        'flighty' : 'B',
        'stoic' : 'A',
        'pushy' : 'C'
    },
    24 : {
        'tolerant' : 'D',
        'conventional' : 'C',
        'stimulating' : 'A',
        "directing" : 'B'
    },
}

scores = {
    1 : {
        'B' : 'D',
        'D' : 'I',
        'A' : 'S',
        'C' : 'C'
    },
    2 : {
        'A' : 'D',
        'C' : 'I',
        'D' : 'S',
        'B' : 'C'
    },
    3 : {
        'C' : 'D',
        'B' : 'I',
        'A' : 'S',
        'D' : 'C'
    },
    4 : {
        'A' : 'D',
        'D' : 'I',
        'C' : 'S',
        'B' : 'C'
    },
    5 : {
        'D' : 'D',
        'B' : 'I',
        'C' : 'S',
        'A' : 'C'
    },
    6 : {
        'B' : 'D',
        'A' : 'I',
        'D' : 'S',
        'C' : 'C'
    },
    7 : {
        'C' : 'D',
        'D' : 'I',
        'B' : 'S',
        'A' : 'C'
    },
    8: {
        'B' : 'D',
        'A' : 'I',
        'D' : 'S',
        'C' : 'C'
    },
    9: {
        'D' : 'D',
        'A' : 'I',
        'C' : 'S',
        'B' : 'C'
    },
    10 : {
        'C' : 'D',
        'B' : 'I',
        'D' : 'S',
        'A' : 'C'
    },
    11 : {
        'A' : 'D',
        'D' : 'I',
        'C' : 'S',
        'B' : 'C'
    },
    12 : {
        'D' : 'D',
        'C' : 'I',
        'A' : 'S',
        'B' : 'C'
    },
    13 : {
        'B' : 'D',
        'A' : 'I',
        'D' : 'S',
        'C' : 'C'
    },
    14 : {
        'C' : 'D',
        'D' : 'I',
        'B' : 'S',
        'A' : 'C'
    },
    15 : {
        'D' : 'D',
        'A' : 'I',
        'C' : 'S',
        'B' : 'C'
    },
    16 : {
        'A' : 'D',
        'B' : 'I',
        'C' : 'S',
        'D' : 'C'
    },
    17 : {
        'B' : 'D',
        'C' : 'I',
        'D' : 'S',
        'A' : 'C'
    },
    18 : {
        'C' : 'D',
        'A' : 'I',
        'B' : 'S',
        'D' : 'C'
    },
    19 : {
        'D' : 'D',
        'B' : 'I',
        'C' : 'S',
        'A' : 'C'
    },
    20 : {
        'A' : 'D',
        'D' : 'I',
        'C' : 'S',
        'B' : 'C'
    },
    21 : {
        'A' : 'D',
        'B' : 'I',
        'C' : 'S',
        'D' : 'C'
    },
    22 : {
        'D' : 'D',
        'C' : 'I',
        'B' : 'S',
        'A' : 'C'
    },
    23 : {
        'D' : 'D',
        'B' : 'I',
        'A' : 'S',
        'C' : 'C'
    },
    24 : {
        'D' : 'D',
        'C' : 'I',
        'A' : 'S',
        'B' : 'C'
    },
}

# %%
qnum = 1
input_word = 'forceful'
answer = test_q[qnum][input_word]
print(answer)
disc_score = scores[qnum][answer]
print(disc_score)
# Out:
# B
# D

# %%
#function to record user answers from test

def test_intake():

    #empty list
    tester_results = []

    #for loop (iteration) through dictionary, requests user answer
    for i in test_q.keys():
        print('enter a word that aligns with you: ')
        print(test_q[i].keys())
        tester_answer = input()
    
#'in' checks if something is in list
#checks to see if user answer is in the dictionary, if it is, it appends users answer to blank list (records user score)
#returns list of users answers (results)
        if tester_answer in test_q[i].keys():
            tester_results.append(tester_answer)

        elif tester_answer == 'q':
            return tester_results

        elif tester_answer not in test_q[i].keys():
            while tester_answer not in test_q[i].keys(): 
                print (f"response not valid, please try again")
                print('enter a word that aligns with you: ')
                print(test_q[i].keys())
                tester_answer = input()
            tester_results.append(tester_answer)


    return tester_results

test_intake()
# Out:
# enter a word that aligns with you:
# dict_keys(['restrained', 'forceful', 'careful', 'expressive'])
# enter a word that aligns with you:
# dict_keys(['pioneering', 'correct', 'exciting', 'satisfied'])
# enter a word that aligns with you:
# dict_keys(['willing', 'animated', 'bold', 'precise'])
# response not valid, please try again
# enter a word that aligns with you:
# dict_keys(['willing', 'animated', 'bold', 'precise'])
# response not valid, please try again
# enter a word that aligns with you:
# dict_keys(['willing', 'animated', 'bold', 'precise'])
# enter a word that aligns with you:
# dict_keys(['argumentative', 'doubting', 'indecisive', 'unpredictable'])
# enter a word that aligns with you:
# dict_keys(['respectful', 'out-going', 'patient', 'daring'])
# ['forceful', 'pioneering', 'willing', 'doubting']

# %%
def test_intake():
    tester_results = []
    for i in test_q.keys():
        print('enter a word that aligns with you: ')
        print(test_q[i].keys())
        tester_answer = input()
    
        if tester_answer in test_q[i].keys():
            tester_results.append(tester_answer)

        if tester_answer == 'q':
            return tester_results

        if tester_answer not in test_q[i].keys():
            while tester_answer not in test_q[i].keys(): 
                print (f"response not valid, please try again")
                print('enter a word that aligns with you: ')
                print(test_q[i].keys())
                tester_answer = input()
            tester_results.append(tester_answer)


    return tester_results

test_intake()

# %%
# input dictionary
inputDictionary = {'Hello': 10, 'Tutorialspoint': 20, 'python': 30}
# creating an empty list
resultList = []
# traversing through each key value pair of a dictionary using items() function
for key, val in inputDictionary.items():
   # appending list of corresponding key-value pair to a list
   resultList.append([key, val])
# printing the resultant list of a dictionary key-values
print(resultList)

# %%
from abc import ABC
from enum import Enum


#initiating
class Tester:
    def __init__(self,main_personality,percentage_disc):
        self.main_personality = main_personality
        self.percentage_disc = percentage_disc

        def __str__(self):
                return f"Your main personality type is.... {self.main_personality}. Your personality percentage in the other domains are......{self.percentage_disc}"
        
#getters
def get_type(self):
        return self.main_personality
    
def get_percentage(self):
        return self.percentage_disc

# %%
# personality type class of all the possible types of personalities a user can generate.
# the class Personality is an Enum. The attributes Personality.DOMINANCE, Personality.INFLUENCE, etc., are enumeration members (or members) and are functionally constants.
#The enum members have names and values (the name of Personality.DOMINANCE is DOMINANCE, the value of Personality.INFLUENCE is 2, etc.)

class Personality(Enum):
    DOMINANCE = 1
    INFLUENCE = 2
    STEADY = 3
    CONSCIENTIOUS = 4

# %%
# Vehicle class for license plate, company name and their type
class Vehicle:
    def __init__(self, licensePlate, companyName, type_of_vehicle):
        self.licensePlate = licensePlate
        self.companyName = companyName
        self.type_of_vehicle = type_of_vehicle

# %%
#classes to be recalled based on score of user

class Dominance(Personality): 
    def __init__(self):
        Personality.__init__(self, 'DOMINANCE', float)

class Influence(Personality):  
    def __init__(self):
        Personality.__init__(self,'INFLUENCE', float)
            
class Conscientious(Personality):  
    def __init__(self):
        Personality.__init__(self,'CONSCIENTIOUS', float)

class Steady(Personality):  
    def __init__(self):
        Personality.__init__(self,'STEADY', float)

# %%
user_answers = {}

intake_answer = input("Enter the word from the list that reasonates with you the most right now.")

if intake_answer == "key_value.keys":
    for value in key_value.values():
        print(value)
        
for i in words.keys():
    print('enter a word that aligns with you: ')
    print(words[i])
    word = input()
    score = scores[i][word]
    user_answers.append(score)

# %%
user_answers = {}

intake_answer = input("Enter the word that reasonates with you the most right now.")

#nested loop through dictionary
if intake_answer == "yes":
    for value in cart_items.values():
        print(value)

#add a free item  
add_item = input("You won a FREE item! What would you like?")

cart_items["items1"] += [add_item]

for cart_items in cart_items.values():
    print("Added! Check your cart below!", cart_items)

#delete an item
deleted_item = input("Woah! Cart full, Enter a number to delete an item?")

deleted_item = cart_items.pop()

print(deleted_item, "Deleted!" , cart_items)
